# %% [markdown]
# # Analysis
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import coffee data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# import weather data
weather = pd.read_csv("../data/weather/weather_output.csv")

# %%
# TODO: Merge these two dataframes together
combined_dfs = pd.merge(coffee, weather, how="inner", on=['year', 'subdivision'])
combined_dfs
# Out:
#    country   subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0   Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 1   Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 2   Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 3   Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 4   Brazil  Minas Gerais  Arabica      22.10  2010             873.0
# 5   Brazil  Minas Gerais  Arabica      28.50  2011             815.0
# 6   Brazil  Minas Gerais  Arabica      23.50  2012             835.0
# 7   Brazil  Minas Gerais  Arabica      28.50  2013            1000.0
# 8   Brazil  Minas Gerais  Arabica      29.40  2014            1055.0
# 9   Brazil  Minas Gerais  Arabica      26.00  2015            1185.0
# 10  Brazil  Minas Gerais  Arabica      25.30  2016            1125.0
# 11  Brazil  Minas Gerais  Arabica      32.50  2017            1300.0
# 12  Brazil  Minas Gerais  Arabica      28.30  2018               NaN
# ...

# %%
# TODO: View the first 5 rows of your data

combined_dfs.head()
# Out:
#   country   subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 1  Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 2  Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 3  Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 4  Brazil  Minas Gerais  Arabica      22.10  2010             873.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         5330.0             175.0            2298.0
# 1         5730.0             186.0            2245.0
# 2         5720.0             196.0            2235.0
# 3         5770.0             188.0            2223.0
# 4         5725.0             244.0            2151.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare  rain_max  \
# 0                     2319.0                        3320.0  6.670968
# 1                     2552.0                        3030.0  1.866250
# ...

# %%
# TODO: Check for null values 

combined_dfs.isnull().sum()
# Out:
# country                         0
# subdivision                     0
# type                            0
# 60kgs_bag                       0
# year                            0
# nonbearing_trees                1
# bearing_trees                   1
# nonbear_hectares                1
# bearing_hectares                1
# bearing_trees_per_hectare       1
# nonbearing_trees_per_hectare    1
# rain_max                        0
# temp_avg                        0
# temp_max                        0
# temp_min                        0
# hum_max                         0
# hum_min                         0
# wind_max                        0
# wind_avg                        0
# dtype: int64

# %%
# TODO: Drop rows that contain null values

combined_dfs = combined_dfs.dropna()
combined_dfs.columns
# Out:
# Index(['country', 'subdivision', 'type', '60kgs_bag', 'year',
#        'nonbearing_trees', 'bearing_trees', 'nonbear_hectares',
#        'bearing_hectares', 'bearing_trees_per_hectare',
#        'nonbearing_trees_per_hectare', 'rain_max', 'temp_avg', 'temp_max',
#        'temp_min', 'hum_max', 'hum_min', 'wind_max', 'wind_avg'],
#       dtype='object')

# %%
# TODO: BEGIN YOUR EDA!
# relationship between temp_avg and 60kgs_bag
sns.scatterplot(combined_dfs, x="60kgs_bag", y="temp_avg")
plt.show()

# %%
# pearson's coefficient btween 60kgs_bag and temp_avg
combined_dfs[["temp_avg", "60kgs_bag"]].corr()
# Out:
#            temp_avg  60kgs_bag
# temp_avg   1.000000  -0.124772
# 60kgs_bag -0.124772   1.000000

# %%
# minimum humidity and 60kgs bags
sns.scatterplot(combined_dfs, x="60kgs_bag", y="hum_min")
plt.show()

# %%
# pearson's coefficient btween 60kgs_bag and hum_min
combined_dfs[["hum_min", "60kgs_bag"]].corr()
# Out:
#             hum_min  60kgs_bag
# hum_min    1.000000  -0.540171
# 60kgs_bag -0.540171   1.000000

# %%
# realtionship between rain_max and 60kgs_bag
sns.scatterplot(combined_dfs, x="60kgs_bag", y="rain_max")
plt.show()

# %%
# pearson's coefficient btween 60kgs_bag and rain_max
combined_dfs[["rain_max", "60kgs_bag"]].corr()
# Out:
#            rain_max  60kgs_bag
# rain_max   1.000000  -0.395811
# 60kgs_bag -0.395811   1.000000

# %%
# Relationship for average wind speed and 60kg bags
sns.scatterplot(combined_dfs, x="60kgs_bag", y="wind_avg")
plt.show()

# %%
# pearson's coefficient btween 60kgs_bag and wind_avg
combined_dfs[["wind_avg", "60kgs_bag"]].corr()
# Out:
#            wind_avg  60kgs_bag
# wind_avg   1.000000  -0.707327
# 60kgs_bag -0.707327   1.000000

# %%
# rain_max and bearing_trees
sns.scatterplot(combined_dfs, y="bearing_trees", x="rain_max")
plt.show()

# %%
# pearson's coefficient between rain_max and bearing_trees
combined_dfs[["bearing_trees", "rain_max"]].corr()
# Out:
#                bearing_trees  rain_max
# bearing_trees       1.000000 -0.332832
# rain_max           -0.332832  1.000000

# %%
# rain_max and wind_max
sns.scatterplot(combined_dfs, y="bearing_trees", x="wind_max")
plt.show()

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# What is the relationship between temp_avg and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The Pearson's correlation coefficient for average temperature in Minas Gerais and the number of 60kgs bags is -0.124, indicating a very weak negative linear relationship between the two. The scatter plot supports this, showing a widely scattered pattern with no clear trend.

# %% [markdown]
# What is the relationship between minimum humidity and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The Pearson's correlation coefficient for 60kg bags of coffee and minimum humidity is -0.54, indicating a moderate negative linear relationship between the two. This implies that as the minimum humidity decreases, the number of coffee bags increases. The scatter plot shows that the lower the humidity, the higher the number of coffee bags.

# %% [markdown]
# What is the relationship between rain_max and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The Pearson's correlation for maximum rain and 60 kg bags of coffee is -0.3958, indicating a moderate negative linear relationship. The scatter plot supports this, showing that the less rainfall, the more coffee bags are produced.

# %% [markdown]
# What is the relationship between average wind speed and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The Pearson's correlation coefficient for average wind speed and 60kg coffee bags is -0.707, indicating a strong negative linear relationship. This suggests that higher wind speeds results in lower coffee production. The scatter plot supports this trend, showing a downward pattern.

# %% [markdown]
# Perform the same bivariate analysis between the mentioned weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column of your choice (bearing_trees, nonbearing_trees, bearing_trees_per_hectare, etc). Which directions do these relationships follow? What are the strengths of these relationships?
#
# The Pearson's correlation coefficient for bearing trees and maximum rain is -0.332, indicating a weak negative linear relationship. The scatter plot shows a decline in bearing trees as the rain increases.

# %% [markdown]
# Which weather factor seems to influence coffee production the most?
#
# Looking at the various Pearson's correlation coefficients produced by the data and the various scatterplots, the factor that is influencing the coffee production the most is wind speed. This could be due to a loss of water from high wind speeds and potential damage to the plants themselves.

# %% [markdown]
# Which data would you collect to continue exploring the impacts of weather and economic forces on coffee production?
#
# I would collect more data on how wind is influencing the growing conditions for the coffee trees, examining the soil mositure levels as well. I would also collect data on soil quality, seasonal weather trends rather than yearly, and if there are any pests destroying the crops.

# %% [markdown]
# If you were preparing a report to provide coffee farmers, which weather conditions would you state are the most favorable for coffee growing (assuming any exist)?
#
# If I was preparing a report to coffee farmers, I would advise that the farmers pick an area with lower wind speeds to prevent damage to the crops, as shown by the strong negative correlation between wind speed and bags produced. I would suggest a climate that is warm (21 degrees Celcius), with high levels of humidty and plenty of rainfall to support the coffee plants.
